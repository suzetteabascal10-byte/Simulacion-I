# %% [markdown]
# <a href="https://colab.research.google.com/github/suzetteabascal10-byte/Simulacion-I/blob/main/prueba_de_kolmogorov_smirnov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prueba de frecuencias
# se realizo con los numeros aleatorios de la anterior actividad dependiendo del intervalo de confianza sus frecuencias así como el valor critico y la suma de frecuencias.

# %%
import scipy.stats as st
from scipy.stats import chi2
import numpy as np
import tabulate

D = [
0.78961, 0.05230, 0.10699, 0.55877, 0.14151,
0.76086, 0.12079, 0.27738, 0.65726, 0.79269,
0.80548, 0.82654, 0.29453, 0.20852, 0.42989,
0.58518, 0.98611, 0.34488, 0.34358, 0.11537,
0.89898, 0.57880, 0.67621, 0.05010, 0.00121,
0.28269, 0.73059, 0.70119, 0.18284, 0.49962,
0.38618, 0.76910, 0.68334, 0.55170, 0.10850,
0.79882, 0.45679, 0.21631, 0.87616, 0.55743,
0.58962, 0.33216, 0.03185, 0.61168, 0.09264,
0.69623, 0.17028, 0.05475, 0.91512, 0.76262,
0.29931, 0.30861, 0.83358, 0.51781, 0.03272,
0.57410, 0.26593, 0.85903, 0.43308, 0.35286,
0.24000, 0.65559, 0.38507, 0.90829, 0.94187,
0.93655, 0.88809, 0.81772, 0.36982, 0.19904,
0.54325, 0.62400, 0.09133, 0.41678, 0.33954,
0.58244, 0.85853, 0.86752, 0.38729, 0.15506,
0.23949, 0.53559, 0.33381, 0.49883, 0.75103,
0.19962, 0.65002, 0.74579, 0.79113, 0.63453,
0.19147, 0.40644, 0.08128, 0.73435, 0.22724,
0.22287, 0.07281, 0.64183, 0.44267, 0.72102
]
n = len(D)

fe = 20
alpha = float(input("ingrese el intervalo de confianza"))
l1 = [x for x in D if 0 <= x <.2]
l2 = [x for x in D if 0.2 <= x <.4]
l3 = [x for x in D if 0.4 <= x <.6]
l4 = [x for x in D if 0.6 <= x <.8]
l5 = [x for x in D if 0.8 <= x <=1]
fe1 = len(l1)
fe2 = len(l2)
fe3 = len(l3)
fe4 = len(l4)
fe5 = len(l5)
print(fe1,fe2,fe3,fe4,fe5)
f = [(fe1-fe)**2 /fe,(fe2-fe)**2 / fe,(fe3-fe)**2 /fe,(fe4-fe)**2 /fe,(fe5-fe)**2 /fe]
s = sum(f)
print(s)
valor_critico = chi2.ppf(0.95,4)
print(valor_critico)
if s < valor_critico:
  print(" la hipotesis nula se acepta, son numeros aleatorios")
else:
  print("la hipotesisi nula se rechaza. son numeros no aleatorios")
# Out:
# ingrese el intervalo de confianza.5
# 21 22 19 23 15
# 2.0
# 9.487729036781154
#  la hipotesis nula se acepta, son numeros aleatorios

# %% [markdown]
# Con lo obtenido anteriormente se realiza una tabla para una mejor visualizacion de los datos

# %%
import pandas as pd

data = {
    'frecuencias': f,
    'valor critico': valor_critico,
    'suma de frecuencia': s
}

# Crear la tabla
df = pd.DataFrame(data)

# Imprimir la tabla
print(df)
# Out:
#    frecuencias  valor critico  suma de frecuencia
# 0         0.05       9.487729                 2.0
# 1         0.20       9.487729                 2.0
# 2         0.05       9.487729                 2.0
# 3         0.45       9.487729                 2.0
# 4         1.25       9.487729                 2.0
